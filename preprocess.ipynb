# %%
import pandas as pd
import os
import shutil
# Out:
# /var/folders/my/rbl5q7yd7pxb2yk9_qjc7mjr0000gn/T/ipykernel_45786/3772222284.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
# paths = ['./train', './test']

# def remove_files(path):
#     for file_name in os.listdir(path):
#         file_path = os.path.join(path, file_name)
#         if os.path.isfile(file_path):
#             os.remove(file_path)
#             print(f"remove: {file_path}")

# for path in paths:
#     if os.path.exists(path):
#         remove_files(path)
#     else:
#         print(f"path does not exists: {path}")

# %%
PATH_TRAIN = './train'
PATH_TEST = './test'

# %%
if(os.path.exists(PATH_TRAIN)):
  shutil.rmtree(PATH_TRAIN)

if(os.path.exists(PATH_TEST)):
  shutil.rmtree(PATH_TEST)

os.makedirs(PATH_TRAIN)
os.makedirs(PATH_TEST)

# %%
df = pd.read_csv('list_attribute.txt', delim_whitespace=True, skiprows=1)
df.describe()
# Out:
# /var/folders/my/rbl5q7yd7pxb2yk9_qjc7mjr0000gn/T/ipykernel_45786/1857780641.py:1: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv('list_attribute.txt', delim_whitespace=True, skiprows=1)
#        5_o_Clock_Shadow  Arched_Eyebrows    Attractive  Bags_Under_Eyes  \
# count     202599.000000    202599.000000  202599.00000    202599.000000
# mean          -0.777728        -0.466039       0.02501        -0.590857
# std            0.628602         0.884766       0.99969         0.806778
# min           -1.000000        -1.000000      -1.00000        -1.000000
# 25%           -1.000000        -1.000000      -1.00000        -1.000000
# 50%           -1.000000        -1.000000       1.00000        -1.000000
# 75%           -1.000000         1.000000       1.00000        -1.000000
# max            1.000000         1.000000       1.00000         1.000000
#
# ...

# %%
file_images = os.listdir('images/')
df_filtered = df[df.index.isin(file_images)]

df_filtered.describe()
# Out:
#        5_o_Clock_Shadow  Arched_Eyebrows   Attractive  Bags_Under_Eyes  \
# count       5000.000000       5000.00000  5000.000000      5000.000000
# mean          -0.785200         -0.46920     0.031200        -0.591200
# std            0.619304          0.88318     0.999613         0.806606
# min           -1.000000         -1.00000    -1.000000        -1.000000
# 25%           -1.000000         -1.00000    -1.000000        -1.000000
# 50%           -1.000000         -1.00000     1.000000        -1.000000
# 75%           -1.000000          1.00000     1.000000        -1.000000
# max            1.000000          1.00000     1.000000         1.000000
#
#               Bald        Bangs     Big_Lips     Big_Nose   Black_Hair  \
# count  5000.000000  5000.000000  5000.000000  5000.000000  5000.000000
# mean     -0.948800    -0.706000    -0.542800    -0.548800    -0.532800
# std       0.315909     0.708283     0.839946     0.836037     0.846326
# ...

# %%
from sklearn.model_selection import train_test_split

df_train, df_test = train_test_split(df_filtered, test_size=0.3)

df_train.describe()
# Out:
#        5_o_Clock_Shadow  Arched_Eyebrows   Attractive  Bags_Under_Eyes  \
# count       3500.000000      3500.000000  3500.000000      3500.000000
# mean          -0.785143        -0.484571     0.017714        -0.597714
# std            0.619403         0.874877     0.999986         0.801824
# min           -1.000000        -1.000000    -1.000000        -1.000000
# 25%           -1.000000        -1.000000    -1.000000        -1.000000
# 50%           -1.000000        -1.000000     1.000000        -1.000000
# 75%           -1.000000         1.000000     1.000000        -1.000000
# max            1.000000         1.000000     1.000000         1.000000
#
#               Bald        Bangs     Big_Lips     Big_Nose   Black_Hair  \
# count  3500.000000  3500.000000  3500.000000  3500.000000  3500.000000
# mean     -0.953143    -0.701143    -0.546286    -0.560000    -0.512571
# std       0.302564     0.713123     0.837719     0.828611     0.858767
# ...

# %%
for index in df_train.index:
  shutil.copy(f'images/{index}', f'train/{index}')

# %%
for index in df_test.index:
  shutil.copy(f'images/{index}', f'test/{index}')

# %% [markdown]
# ---
